# %% [markdown]
# ### Variables

# %%
x = 10

# %%
print(x)
# Out:
# 10

# %% [markdown]
# There are 3 basic types:
# Number(Integer or Float) or a String

# %%
age = 10
price = 23.5
product_name = "Onion"

# %%
print("The Type of age variable is: ",type(age))
print("The Type of price variable is: ",type(price))
print("The Type of product_name variable is: ",type(product_name))
# Out:
# The Type of age variable is:  <class 'int'>
# The Type of price variable is:  <class 'float'>
# The Type of product_name variable is:  <class 'str'>

# %% [markdown]
# #### Rules of Naming
# 1. Must start with a letter
# 2. Can contain Number or underscore(`_`)
# 3. Single Word (No Space inbetween)
# 4. Must not be a Keyword

# %%
principal = 300000
time_in_months = 36
rate_of_interest = 0.07

simple_interest = (principal * time_in_months * rate_of_interest) / 100
print("The Simple interest is: ", simple_interest)
# Out:
# The Simple interest is:  7560.000000000001

# %%
principal = float(input("Enter the Principal: "))
time_in_months = int(input("Enter the time in months: "))
rate_of_interest = float(input("Enter the rate of interest in decimal(Eg: 7% is 0.07):"))

simple_interest = (principal * time_in_months * rate_of_interest) / 100
print("The Simple interest is: ", simple_interest)
# Out:
# The Simple interest is:  75600.00000000001
